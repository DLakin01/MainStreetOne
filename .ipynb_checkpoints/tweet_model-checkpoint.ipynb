# %% [markdown]
# # Tweet Gender Classification with NLP, Scikit-Learn, and LightGBM
# #### *Daniel Lakin*
# ---
# In this notebook, we use various a combination of machine learning and linguistic processing tools to build
# a model that can predict, given an individual tweet, the author's gender. Working from an archived set of files,
# we extract raw data on tweets from 200 individual users, and supplement the data with a call to Twitter's API. We
# then extract new linguistic and categorical features on each tweet, working primarily from the posted text.
#
# After feature extraction and scaling, we feed it into a series of Microsoft LightGBM Gradient Boosting Classifiers,
# taking advantage of the power and speed offered by the algorithm. The models are tuned using a randomized search
# cross-validation approach, and we explore the possible benefits of enhancing our results with grid search.
#
# To run the below code, please place the archive with the tweet data (mso_ds_interview.tgz) in the same directory as this notebook, and ensure you have the following Python packages installed, either via pip or in a conda environment:
#
# - matplotlib
# - spacymoji
# - lightgbm
# - textblob
# - jupyter
# - seaborn
# - sklearn
# - requests
# - pandas
# - numpy
# - spacy
# - shap

# %%
import matplotlib.pyplot as plt
import lightgbm as lgb
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import warnings
import tarfile
import random
import spacy
import json
import shap
import re

from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve, average_precision_score
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from emoji import UNICODE_EMOJI, UNICODE_EMOJI_ALIAS
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from requests.auth import HTTPBasicAuth
from sklearn.pipeline import Pipeline
from tarfile import ExFileObject
from textblob import TextBlob
from itertools import product
from spacymoji import Emoji
from pprint import pprint

# %matplotlib inline
shap.initjs()

TWEET_COLUMNS = ["id", "combined_text", "language", "num_mentions", "num_hashtags", "gender"]
TWITTER_ROOT_URL = "https://api.twitter.com"
TWITTER_CONSUMER_KEY = "3RZxLkkQFDMnN3epDPOcP61hP"
TWITTER_CONSUMER_SECRET = "cwfoe7umOC4tAIJE4VmirEjmQE2NPWlnfCr91jS0EQUiOB4cNk"
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %% [markdown]
# In the following section, we unzip the archive containing our data, and parse the `manifest.jl` file, which contains
# unique IDs for each user in the dataset, as well as their gender, denoted by M for male and F for female. We'll be
# using the gender data as our label data later in the process.

# %%
def parse_julia_file(tarfile: ExFileObject):
    tar_string = tarfile.read().decode()
    return [json.loads(el) for el in tar_string.split("\n") if el != ""]


tar = tarfile.open("mso_ds_interview.tgz", "r")
manifest = tar.extractfile("ds_interview/manifest.jl")
manifest_details = parse_julia_file(manifest)
pprint(manifest_details)
# Out:
# [{'gender_human': 'M', 'num_tweets': 3866, 'user_id_str': 1032653820},
#  {'gender_human': 'M', 'num_tweets': 6421, 'user_id_str': 24105930},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 118611310},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 561711469},
#  {'gender_human': 'M', 'num_tweets': 3103, 'user_id_str': 22289976},
#  {'gender_human': 'M', 'num_tweets': 3179, 'user_id_str': 516151662},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 63987770},
#  {'gender_human': 'M', 'num_tweets': 4633, 'user_id_str': 462528800},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 85135716},
#  {'gender_human': 'M', 'num_tweets': 3049, 'user_id_str': 2431301671},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 53222655},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 832787665},
#  {'gender_human': 'M', 'num_tweets': 3173, 'user_id_str': 592874914},
#  {'gender_human': 'M', 'num_tweets': 2792, 'user_id_str': 1729708327},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 556765809},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 1395393222},
#  {'gender_human': 'M', 'num_tweets': 5915, 'user_id_str': 210673102},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 630735042},
#  {'gender_human': 'M', 'num_tweets': 3174, 'user_id_str': 2986507937},
#  {'gender_human': 'M', 'num_tweets': 3033, 'user_id_str': 4922756519},
#  {'gender_human': 'M', 'num_tweets': 5921, 'user_id_str': 191286076},
#  {'gender_human': 'M', 'num_tweets': 4340, 'user_id_str': 1915617937},
#  {'gender_human': 'M', 'num_tweets': 2281, 'user_id_str': 2777876139},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 2611719906},
#  {'gender_human': 'M', 'num_tweets': 3183, 'user_id_str': 39545083},
#  {'gender_human': 'M', 'num_tweets': 3524, 'user_id_str': 132365720},
#  {'gender_human': 'M', 'num_tweets': 3348, 'user_id_str': 1279383703},
#  {'gender_human': 'M', 'num_tweets': 3647, 'user_id_str': 77317813},
#  {'gender_human': 'M', 'num_tweets': 2971, 'user_id_str': 2285630996},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 20334811},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 282584884},
#  {'gender_human': 'M', 'num_tweets': 4250, 'user_id_str': 594479233},
#  {'gender_human': 'M', 'num_tweets': 8495, 'user_id_str': 154973097},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 49095122},
#  {'gender_human': 'M', 'num_tweets': 3196, 'user_id_str': 589450275},
#  {'gender_human': 'M', 'num_tweets': 3189, 'user_id_str': 270092489},
#  {'gender_human': 'M', 'num_tweets': 2638, 'user_id_str': 47134306},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 304625987},
#  {'gender_human': 'M', 'num_tweets': 2968, 'user_id_str': 733288489},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 512613676},
#  {'gender_human': 'M', 'num_tweets': 3148, 'user_id_str': 316920144},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 29003791},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 45352666},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 1639305888},
#  {'gender_human': 'M', 'num_tweets': 2204, 'user_id_str': 539444670},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 2335699553},
#  {'gender_human': 'M', 'num_tweets': 3131, 'user_id_str': 3062932443},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 499307143},
#  {'gender_human': 'M', 'num_tweets': 3139, 'user_id_str': 2306417605},
#  {'gender_human': 'M', 'num_tweets': 3120, 'user_id_str': 1025884050},
#  {'gender_human': 'M', 'num_tweets': 6402, 'user_id_str': 17331851},
#  {'gender_human': 'M', 'num_tweets': 3147, 'user_id_str': 2624112243},
#  {'gender_human': 'M', 'num_tweets': 4616, 'user_id_str': 408217165},
#  {'gender_human': 'M', 'num_tweets': 6398, 'user_id_str': 17616581},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 2202275642},
#  {'gender_human': 'M', 'num_tweets': 3174, 'user_id_str': 294273610},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 296769899},
#  {'gender_human': 'M', 'num_tweets': 3130, 'user_id_str': 2934744605},
#  {'gender_human': 'M', 'num_tweets': 2553, 'user_id_str': 3362616755},
#  {'gender_human': 'M', 'num_tweets': 6401, 'user_id_str': 1071792841},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 98361433},
#  {'gender_human': 'M', 'num_tweets': 2727, 'user_id_str': 2869639827},
#  {'gender_human': 'M', 'num_tweets': 3181, 'user_id_str': 625153673},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 453619947},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 853648609},
#  {'gender_human': 'M', 'num_tweets': 5381, 'user_id_str': 3777644237},
#  {'gender_human': 'M', 'num_tweets': 3083, 'user_id_str': 372757984},
#  {'gender_human': 'M', 'num_tweets': 6389, 'user_id_str': 427904994},
#  {'gender_human': 'M', 'num_tweets': 3302, 'user_id_str': 291743551},
#  {'gender_human': 'M', 'num_tweets': 3082, 'user_id_str': 1715181804},
#  {'gender_human': 'M', 'num_tweets': 3196, 'user_id_str': 33395496},
#  {'gender_human': 'M', 'num_tweets': 3165, 'user_id_str': 860111966},
#  {'gender_human': 'M', 'num_tweets': 7231, 'user_id_str': 18981284},
#  {'gender_human': 'M', 'num_tweets': 2475, 'user_id_str': 1890726134},
#  {'gender_human': 'M', 'num_tweets': 3089, 'user_id_str': 403816682},
#  {'gender_human': 'M', 'num_tweets': 3151, 'user_id_str': 2877897322},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 170529805},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 2538284166},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 374689687},
#  {'gender_human': 'M', 'num_tweets': 3177, 'user_id_str': 2895530079},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 250904678},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 836975329},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 1067521734},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 1465588758},
#  {'gender_human': 'M', 'num_tweets': 3872, 'user_id_str': 70111991},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 466025642},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 2280224390},
#  {'gender_human': 'M', 'num_tweets': 6382, 'user_id_str': 3280114826},
#  {'gender_human': 'M', 'num_tweets': 3183, 'user_id_str': 1368334873},
#  {'gender_human': 'M', 'num_tweets': 6409, 'user_id_str': 3459015855},
#  {'gender_human': 'M', 'num_tweets': 3198, 'user_id_str': 21220828},
#  {'gender_human': 'M', 'num_tweets': 8009, 'user_id_str': 1561800522},
#  {'gender_human': 'M', 'num_tweets': 4939, 'user_id_str': 563278347},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 138648805},
#  {'gender_human': 'M', 'num_tweets': 3122, 'user_id_str': 2879513675},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 1361347831},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 129558263},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 920392261},
#  {'gender_human': 'M', 'num_tweets': 3200, 'user_id_str': 498567313},
#  {'gender_human': 'M', 'num_tweets': 6985, 'user_id_str': 1293604357},
#  {'gender_human': 'F', 'num_tweets': 3177, 'user_id_str': 419082859},
#  {'gender_human': 'F', 'num_tweets': 3092, 'user_id_str': 1449156420},
#  {'gender_human': 'F', 'num_tweets': 6387, 'user_id_str': 559939813},
#  {'gender_human': 'F', 'num_tweets': 2977, 'user_id_str': 3103368284},
#  {'gender_human': 'F', 'num_tweets': 3109, 'user_id_str': 2196041740},
#  {'gender_human': 'F', 'num_tweets': 5145, 'user_id_str': 60959702},
#  {'gender_human': 'F', 'num_tweets': 3183, 'user_id_str': 334851249},
#  {'gender_human': 'F', 'num_tweets': 3097, 'user_id_str': 1173326354},
#  {'gender_human': 'F', 'num_tweets': 3156, 'user_id_str': 499353626},
#  {'gender_human': 'F', 'num_tweets': 3196, 'user_id_str': 628005464},
#  {'gender_human': 'F', 'num_tweets': 2317, 'user_id_str': 261466327},
#  {'gender_human': 'F', 'num_tweets': 3175, 'user_id_str': 3270186660},
#  {'gender_human': 'F', 'num_tweets': 3179, 'user_id_str': 156796820},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 119606739},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 1018514046},
#  {'gender_human': 'F', 'num_tweets': 6354, 'user_id_str': 160794196},
#  {'gender_human': 'F', 'num_tweets': 3172, 'user_id_str': 98830119},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 27169592},
#  {'gender_human': 'F', 'num_tweets': 8139, 'user_id_str': 1599485347},
#  {'gender_human': 'F', 'num_tweets': 4093, 'user_id_str': 368368623},
#  {'gender_human': 'F', 'num_tweets': 3014, 'user_id_str': 204041871},
#  {'gender_human': 'F', 'num_tweets': 3545, 'user_id_str': 1648364232},
#  {'gender_human': 'F', 'num_tweets': 3310, 'user_id_str': 511260971},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 3247591823},
#  {'gender_human': 'F', 'num_tweets': 3181, 'user_id_str': 2148676287},
#  {'gender_human': 'F', 'num_tweets': 3177, 'user_id_str': 3105960879},
#  {'gender_human': 'F', 'num_tweets': 3149, 'user_id_str': 229050637},
#  {'gender_human': 'F', 'num_tweets': 3168, 'user_id_str': 104025767},
#  {'gender_human': 'F', 'num_tweets': 2842, 'user_id_str': 746480464517464064},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 23719482},
#  {'gender_human': 'F', 'num_tweets': 3166, 'user_id_str': 193717643},
#  {'gender_human': 'F', 'num_tweets': 3613, 'user_id_str': 719371176},
#  {'gender_human': 'F', 'num_tweets': 3061, 'user_id_str': 1257881568},
#  {'gender_human': 'F', 'num_tweets': 3071, 'user_id_str': 1918439197},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 985526550},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 3799822333},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 497278601},
#  {'gender_human': 'F', 'num_tweets': 3100, 'user_id_str': 2466560409},
#  {'gender_human': 'F', 'num_tweets': 3185, 'user_id_str': 603296177},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 54790074},
#  {'gender_human': 'F', 'num_tweets': 3137, 'user_id_str': 710108327},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 229968740},
#  {'gender_human': 'F', 'num_tweets': 6368, 'user_id_str': 933608750},
#  {'gender_human': 'F', 'num_tweets': 2807, 'user_id_str': 442872731},
#  {'gender_human': 'F', 'num_tweets': 6293, 'user_id_str': 3105486589},
#  {'gender_human': 'F', 'num_tweets': 4009, 'user_id_str': 246421163},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 2273826823},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 191756800},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 2158883731},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 622451405},
#  {'gender_human': 'F', 'num_tweets': 6220, 'user_id_str': 749751871},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 4914921064},
#  {'gender_human': 'F', 'num_tweets': 3160, 'user_id_str': 2543423662},
#  {'gender_human': 'F', 'num_tweets': 3131, 'user_id_str': 452114868},
#  {'gender_human': 'F', 'num_tweets': 3180, 'user_id_str': 335764522},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 295369021},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 329324377},
#  {'gender_human': 'F', 'num_tweets': 3097, 'user_id_str': 155210468},
#  {'gender_human': 'F', 'num_tweets': 2562, 'user_id_str': 3434928448},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 247621645},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 46505495},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 286553425},
#  {'gender_human': 'F', 'num_tweets': 2927, 'user_id_str': 423449075},
#  {'gender_human': 'F', 'num_tweets': 4502, 'user_id_str': 40108249},
#  {'gender_human': 'F', 'num_tweets': 3163, 'user_id_str': 558258110},
#  {'gender_human': 'F', 'num_tweets': 3170, 'user_id_str': 1161531193},
#  {'gender_human': 'F', 'num_tweets': 3137, 'user_id_str': 168787883},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 2853689799},
#  {'gender_human': 'F', 'num_tweets': 3195, 'user_id_str': 848249960},
#  {'gender_human': 'F', 'num_tweets': 6357, 'user_id_str': 3918171040},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 526956434},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 46933124},
#  {'gender_human': 'F', 'num_tweets': 3264, 'user_id_str': 85131516},
#  {'gender_human': 'F', 'num_tweets': 3560, 'user_id_str': 367206382},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 817100042},
#  {'gender_human': 'F', 'num_tweets': 3190, 'user_id_str': 73045587},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 53697067},
#  {'gender_human': 'F', 'num_tweets': 3192, 'user_id_str': 480721333},
#  {'gender_human': 'F', 'num_tweets': 6390, 'user_id_str': 37352356},
#  {'gender_human': 'F', 'num_tweets': 3157, 'user_id_str': 729464735297458176},
#  {'gender_human': 'F', 'num_tweets': 3181, 'user_id_str': 3319171713},
#  {'gender_human': 'F', 'num_tweets': 3084, 'user_id_str': 514327752},
#  {'gender_human': 'F', 'num_tweets': 6422, 'user_id_str': 15811630},
#  {'gender_human': 'F', 'num_tweets': 3106, 'user_id_str': 740264622},
#  {'gender_human': 'F', 'num_tweets': 6376, 'user_id_str': 262828122},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 588671864},
#  {'gender_human': 'F', 'num_tweets': 6220, 'user_id_str': 908039828},
#  {'gender_human': 'F', 'num_tweets': 3070, 'user_id_str': 1954987574},
#  {'gender_human': 'F', 'num_tweets': 3129, 'user_id_str': 2616095807},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 19808025},
#  {'gender_human': 'F', 'num_tweets': 3137, 'user_id_str': 627491498},
#  {'gender_human': 'F', 'num_tweets': 6396, 'user_id_str': 412412198},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 618367558},
#  {'gender_human': 'F', 'num_tweets': 4146, 'user_id_str': 2699297516},
#  {'gender_human': 'F', 'num_tweets': 6418, 'user_id_str': 79819220},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 3233530041},
#  {'gender_human': 'F', 'num_tweets': 3200, 'user_id_str': 4317765573},
#  {'gender_human': 'F', 'num_tweets': 3586, 'user_id_str': 46864800},
#  {'gender_human': 'F', 'num_tweets': 3158, 'user_id_str': 99582781},
#  {'gender_human': 'F', 'num_tweets': 3190, 'user_id_str': 24487757}]

# %% [markdown]
# Using the unique IDs extracted from manifest.jl, we can then use the same parse_julia_file method defined above to
# pull the information for each of the 200 users. For each user, we also pull their profile description via the
# Twitter API.

# %%
tweets_data_list = []

# Authenticate to Twitter API
auth = HTTPBasicAuth("3RZxLkkQFDMnN3epDPOcP61hP", "cwfoe7umOC4tAIJE4VmirEjmQE2NPWlnfCr91jS0EQUiOB4cNk")
auth_response = requests.post("https://api.twitter.com/oauth2/token?grant_type=client_credentials", auth=auth).json()
headers = {"Authorization": f"Bearer {auth_response['access_token']}"}


def parse_tweet_text(tweet_obj: dict):
    try:
        text = tweet_obj["full_text"]
        if text == "":
            text = tweet_obj["text"]

    except KeyError:
        text = tweet_obj["text"]

    return text


with requests.session() as session:
    session.headers = headers

    for user in manifest_details:
        user_id = user["user_id_str"]
        print(f"Pulling tweets for user {user_id}")

        api_result = session.get(f"https://api.twitter.com/1.1/users/lookup.json?user_id={user_id}").json()
        if "errors" in api_result:
            profile_description = ""

        else:
            profile_description = api_result[0]["description"]

        tweet_file = tar.extractfile(f"ds_interview/tweet_files/{user_id}.tweets.jl")
        user_tweets = parse_julia_file(tweet_file)

        for t in user_tweets:
            tdoc = t["document"]
            tweet_id = tdoc["id"]
            combined_text = parse_tweet_text(tdoc) + " " + profile_description
            language = tdoc["lang"]
            num_mentions = len(tdoc["entities"]["user_mentions"])
            num_hashtags = len(tdoc["entities"]["hashtags"])

            tweets_data_list.append([
                tweet_id,
                combined_text,
                language,
                num_mentions,
                num_hashtags,
                user["gender_human"]
            ])
# Out:
# Pulling tweets for user 1032653820
# Pulling tweets for user 24105930
# Pulling tweets for user 118611310
# Pulling tweets for user 561711469
# Pulling tweets for user 22289976
# Pulling tweets for user 516151662
# Pulling tweets for user 63987770
# Pulling tweets for user 462528800
# Pulling tweets for user 85135716
# Pulling tweets for user 2431301671
# Pulling tweets for user 53222655
# Pulling tweets for user 832787665
# Pulling tweets for user 592874914
# Pulling tweets for user 1729708327
# Pulling tweets for user 556765809
# Pulling tweets for user 1395393222
# Pulling tweets for user 210673102
# Pulling tweets for user 630735042
# Pulling tweets for user 2986507937
# Pulling tweets for user 4922756519
# Pulling tweets for user 191286076
# Pulling tweets for user 1915617937
# Pulling tweets for user 2777876139
# Pulling tweets for user 2611719906
# Pulling tweets for user 39545083
# Pulling tweets for user 132365720
# Pulling tweets for user 1279383703
# Pulling tweets for user 77317813
# Pulling tweets for user 2285630996
# Pulling tweets for user 20334811
# Pulling tweets for user 282584884
# Pulling tweets for user 594479233
# Pulling tweets for user 154973097
# Pulling tweets for user 49095122
# Pulling tweets for user 589450275
# Pulling tweets for user 270092489
# Pulling tweets for user 47134306
# Pulling tweets for user 304625987
# Pulling tweets for user 733288489
# Pulling tweets for user 512613676
# Pulling tweets for user 316920144
# Pulling tweets for user 29003791
# Pulling tweets for user 45352666
# Pulling tweets for user 1639305888
# Pulling tweets for user 539444670
# Pulling tweets for user 2335699553
# Pulling tweets for user 3062932443
# Pulling tweets for user 499307143
# Pulling tweets for user 2306417605
# Pulling tweets for user 1025884050
# Pulling tweets for user 17331851
# Pulling tweets for user 2624112243
# Pulling tweets for user 408217165
# Pulling tweets for user 17616581
# Pulling tweets for user 2202275642
# Pulling tweets for user 294273610
# Pulling tweets for user 296769899
# Pulling tweets for user 2934744605
# Pulling tweets for user 3362616755
# Pulling tweets for user 1071792841
# Pulling tweets for user 98361433
# Pulling tweets for user 2869639827
# Pulling tweets for user 625153673
# Pulling tweets for user 453619947
# Pulling tweets for user 853648609
# Pulling tweets for user 3777644237
# Pulling tweets for user 372757984
# Pulling tweets for user 427904994
# Pulling tweets for user 291743551
# Pulling tweets for user 1715181804
# Pulling tweets for user 33395496
# Pulling tweets for user 860111966
# Pulling tweets for user 18981284
# Pulling tweets for user 1890726134
# Pulling tweets for user 403816682
# Pulling tweets for user 2877897322
# Pulling tweets for user 170529805
# Pulling tweets for user 2538284166
# Pulling tweets for user 374689687
# Pulling tweets for user 2895530079
# Pulling tweets for user 250904678
# Pulling tweets for user 836975329
# Pulling tweets for user 1067521734
# Pulling tweets for user 1465588758
# Pulling tweets for user 70111991
# Pulling tweets for user 466025642
# Pulling tweets for user 2280224390
# Pulling tweets for user 3280114826
# Pulling tweets for user 1368334873
# Pulling tweets for user 3459015855
# Pulling tweets for user 21220828
# Pulling tweets for user 1561800522
# Pulling tweets for user 563278347
# Pulling tweets for user 138648805
# Pulling tweets for user 2879513675
# Pulling tweets for user 1361347831
# Pulling tweets for user 129558263
# Pulling tweets for user 920392261
# Pulling tweets for user 498567313
# Pulling tweets for user 1293604357
# Pulling tweets for user 419082859
# Pulling tweets for user 1449156420
# Pulling tweets for user 559939813
# Pulling tweets for user 3103368284
# Pulling tweets for user 2196041740
# Pulling tweets for user 60959702
# Pulling tweets for user 334851249
# Pulling tweets for user 1173326354
# Pulling tweets for user 499353626
# Pulling tweets for user 628005464
# Pulling tweets for user 261466327
# Pulling tweets for user 3270186660
# Pulling tweets for user 156796820
# Pulling tweets for user 119606739
# Pulling tweets for user 1018514046
# Pulling tweets for user 160794196
# Pulling tweets for user 98830119
# Pulling tweets for user 27169592
# Pulling tweets for user 1599485347
# Pulling tweets for user 368368623
# Pulling tweets for user 204041871
# Pulling tweets for user 1648364232
# Pulling tweets for user 511260971
# Pulling tweets for user 3247591823
# Pulling tweets for user 2148676287
# Pulling tweets for user 3105960879
# Pulling tweets for user 229050637
# Pulling tweets for user 104025767
# Pulling tweets for user 746480464517464064
# Pulling tweets for user 23719482
# Pulling tweets for user 193717643
# Pulling tweets for user 719371176
# Pulling tweets for user 1257881568
# Pulling tweets for user 1918439197
# Pulling tweets for user 985526550
# Pulling tweets for user 3799822333
# Pulling tweets for user 497278601
# Pulling tweets for user 2466560409
# Pulling tweets for user 603296177
# Pulling tweets for user 54790074
# Pulling tweets for user 710108327
# Pulling tweets for user 229968740
# Pulling tweets for user 933608750
# Pulling tweets for user 442872731
# Pulling tweets for user 3105486589
# Pulling tweets for user 246421163
# Pulling tweets for user 2273826823
# Pulling tweets for user 191756800
# Pulling tweets for user 2158883731
# Pulling tweets for user 622451405
# Pulling tweets for user 749751871
# Pulling tweets for user 4914921064
# Pulling tweets for user 2543423662
# Pulling tweets for user 452114868
# Pulling tweets for user 335764522
# Pulling tweets for user 295369021
# Pulling tweets for user 329324377
# Pulling tweets for user 155210468
# Pulling tweets for user 3434928448
# Pulling tweets for user 247621645
# Pulling tweets for user 46505495
# Pulling tweets for user 286553425
# Pulling tweets for user 423449075
# Pulling tweets for user 40108249
# Pulling tweets for user 558258110
# Pulling tweets for user 1161531193
# Pulling tweets for user 168787883
# Pulling tweets for user 2853689799
# Pulling tweets for user 848249960
# Pulling tweets for user 3918171040
# Pulling tweets for user 526956434
# Pulling tweets for user 46933124
# Pulling tweets for user 85131516
# Pulling tweets for user 367206382
# Pulling tweets for user 817100042
# Pulling tweets for user 73045587
# Pulling tweets for user 53697067
# Pulling tweets for user 480721333
# Pulling tweets for user 37352356
# Pulling tweets for user 729464735297458176
# Pulling tweets for user 3319171713
# Pulling tweets for user 514327752
# Pulling tweets for user 15811630
# Pulling tweets for user 740264622
# Pulling tweets for user 262828122
# Pulling tweets for user 588671864
# Pulling tweets for user 908039828
# Pulling tweets for user 1954987574
# Pulling tweets for user 2616095807
# Pulling tweets for user 19808025
# Pulling tweets for user 627491498
# Pulling tweets for user 412412198
# Pulling tweets for user 618367558
# Pulling tweets for user 2699297516
# Pulling tweets for user 79819220
# Pulling tweets for user 3233530041
# Pulling tweets for user 4317765573
# Pulling tweets for user 46864800
# Pulling tweets for user 99582781
# Pulling tweets for user 24487757

# %% [markdown]
# Now that we've pulled and processed data on all the tweets, let's assemble it all into a Pandas Dataframe and take a look at what we have. As we can see below, the dataframe contains the following columns:
#
# - Unique tweet ID
# - Text of tweet + the user's profile description
# - The language the tweet was written in
# - The number of mentions in the tweet
# - The number of hashtags in the tweet

# %%
tweets_df = pd.DataFrame(tweets_data_list, columns=TWEET_COLUMNS)
tweets_df.set_index("id", inplace=True)
tweets_df.head(20)
# Out:
#                                                         combined_text  \
# id
# 955407596458074113  @ConanOBrien I been to that resort in Haiti, t...
# 955404635816255494  @THEAlleyeceeing @VP @clairecmc This is Standa...
# 955227411368562688  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955226565993992194  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955226020935815169  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955225604718321670  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955225361289183234  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955224133721346048  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955223907946127361  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955223506085695493  @zacpell @CHUCKS_MOM @csb2504 @desertcranes @R...
# 955221942302363650  @D_Wallace14 Nick Saban and Bill Belichick bel...
# 955216727910113282  @sallykohn Do you ever get tired of talking po...
# 955158069268361218  @SenDuckworth You need to quit acting like you...
# 955120846124838912  @MarkRuffalo Please stay, you probably smell l...
# 955110537154744322  RT @MightyGopher1: @AmericanVet3 @ReginaldBTur...
# 955065806227898371  @CHUCKS_MOM @csb2504 @desertcranes @ReginaldBT...
# 955065166873415680  @ReginaldBTurner @desertcranes @RepMarkMeadows...
# 955064367749484546  @nowthisnews Also Navy Federal Credit Union wi...
# 955063636384518144  @nowthisnews Well now, maybe we should see the...
# 955062088434626561  RT @RepMarkMeadows: Please share if you agree:...
#
#                    language  num_mentions  num_hashtags gender
# id
# 955407596458074113       en             1             1      M
# 955404635816255494       en             3             0      M
# 955227411368562688       en             6             0      M
# 955226565993992194       en             6             0      M
# 955226020935815169       en             6             0      M
# 955225604718321670       en             6             0      M
# 955225361289183234       en             6             0      M
# 955224133721346048       en             6             0      M
# 955223907946127361      und             6             0      M
# 955223506085695493       en             6             0      M
# 955221942302363650       en             1             0      M
# 955216727910113282       en             1             0      M
# 955158069268361218       en             1             0      M
# 955120846124838912       en             1             0      M
# 955110537154744322       en             5             0      M
# 955065806227898371       en             5             0      M
# 955065166873415680       en             3             0      M
# 955064367749484546       en             1             0      M
# 955063636384518144       en             1             0      M
# 955062088434626561       en             1             0      M

# %% [markdown]
# Looks like we have more than one language present in our data! Before proceeding, let's check to see the distribution of languages across the entire dataset.

# %%
language_counts = tweets_df.groupby("language").count()["combined_text"]
language_counts
# Out:
# language
# ar         15
# bg         37
# cs        787
# cy        290
# da        315
# de        746
# el          9
# en     650075
# es       4499
# et        701
# eu        159
# fi        150
# fr       1667
# hi        327
# ht       1946
# hu        151
# in       5345
# is         95
# it        649
# iw          1
# ja        913
# ko       1883
# lt        135
# lv        141
# ne          2
# nl        611
# no        254
# pl       1390
# pt       7590
# ro        190
# ru       2719
# sl         48
# sr          8
# sv        326
# ta          1
# th       1843
# tl       3201
# tr        322
# uk         43
# und     46032
# vi         35
# zh         46
# Name: combined_text, dtype: int64

# %% [markdown]
# As we can see, there are over 40 languges present in the dataset, with English being the vast majority (over
# 88%). While this introduces some complexity, we can cope with it - the excellent NLP library spaCy provides strong
# support across multiple languages. In the interest of preserving as much of the data as possible, we'll narrow our
# dataframe to include tweets only in the languages spaCy can "understand", and proceed with linguistic feature
# extraction.

# %%
SPACY_LANGS = ["de", "el", "en", "es", "fr", "it", "lt", "nb", "nl", "pt"]

# Throw out samples that spaCy can't parse
tweets_df = tweets_df[tweets_df["language"].isin(SPACY_LANGS)]

language_counts = tweets_df.groupby("language").count()["combined_text"]
language_counts
# Out:
# language
# de       746
# el         9
# en    650075
# es      4499
# fr      1667
# it       649
# lt       135
# nl       611
# pt      7590
# Name: combined_text, dtype: int64

# %% [markdown]
# After narrowing the dataset based on language, we now take another step to reduce the size of the data we're working
# with. Even with only spaCy-friendly languages, the dataset still contains over 650,000 tweets, which will be very
# computationally expensive to work with. To make things easier but still keep the modeling process robust, we'll take
# a 20% sample of the data and use that from now on.

# %%
tweets_df = tweets_df.sample(frac=0.2, random_state=42)
tweets_df.shape

# %% [markdown]
# With the size of the data reduced to a more manageable level, we can begin our linguistic processing and feature
# extraction. In the below section, we work with one language group at a time, running each one through a suite of
# linguistic checks, leveraging spaCy's ability to parse out parts of speech and other features from our chosen
# languages. We also collect information on the number of contractions and emoticons in each tweet, as well as it's
# sentiment (positive, neutral, negative) as detected by the Textblob library's sentiment parser.
#
# I've chosen to collect feature information on all the parts of speech that spaCy can recognize in the languages indicated above, as well as tweet sentiment, on the theory that there are detectable and generalizeable patterns in language usage that will allow a model to tell the gender of a person by looking at their tweet. This step will take ~3 minutes to complete.

# %%
CONTRACTIONS = ["ain't", "aren't", "can't", "can't've", "'cause", "could've", "couldn't", "couldn't've", "didn't",
                "doesn't", "don't", "hadn't", "hadn't've", "hasn't", "haven't", "he'd", "he'd've", "he'll", "he'll've",
                "he's", "how'd", "how'd'y", "how'll", "how's", "I'd", "I'd've", "I'll", "I'll've", "I'm", "I've", "i'd",
                "i'd've", "i'll", "i'll've", "i'm", "i've", "isn't", "it'd", "it'd've", "it'll", "it'll've", "it's",
                "let's", "ma'am", "mayn't", "might've", "mightn't", "mightn't've", "must've", "mustn't", "mustn't've",
                "needn't", "needn't've", "o'clock", "oughtn't", "oughtn't've", "shan't", "sha'n't", "shan't've",
                "she'd", "she'd've", "she'll", "she'll've", "she's", "should've", "shouldn't", "shouldn't've", "so've",
                "so's", "that'd", "that'd've", "that's", "there'd", "there'd've", "there's", "they'd", "they'd've",
                "they'll", "they'll've", "they're", "they've", "to've", "wasn't", "we'd", "we'd've", "we'll",
                "we'll've", "we're", "we've", "weren't", "what'll", "what'll've", "what're", "what's", "what've",
                "when's", "when've", "where'd", "where's", "where've", "who'll", "who'll've", "who's", "who've",
                "why's", "why've", "will've", "won't", "won't've", "would've", "wouldn't", "wouldn't've", "y'all",
                "y'all'd", "y'all'd've", "y'all're", "y'all've", "you'd", "you'd've", "you'll", "you'll've", "you're",
                "you've"]
POS_MAP = {
    "ADJ": "num_adjectives",
    "ADV": "num_adverbs",
    "CONJ": "num_conjunctions",
    "NOUN": "num_nouns",
    "NUM": "num_numerals",
    "PART": "num_particles",
    "PRON": "num_pronouns",
    "PROPN": "num_proper_nouns",
    "PUNCT": "num_punctuation_mks",
    "VERB": "num_verbs"
}


def extract_linguistic_features(texts, tweet_ids, spacy_nlp):
    all_features = []

    for i, doc in enumerate(spacy_nlp.pipe(texts, disable=["tagger", "parser", "ner"], n_threads=16, batch_size=10000)):
        features = {
            "id": tweet_ids[i],
            "num_words": len(doc),
            "tweet_length": len(doc.text),
            "num_exclamation_pts": doc.text.count("!"),
            "num_question_mks": doc.text.count("?"),
            "num_periods": doc.text.count("."),
            "num_hyphens": doc.text.count("-"),
            "num_capitals": sum(1 for char in doc.text if char.isupper()),
            "num_emoticons": sum(
                1 for token in doc
                if token._.is_emoji
                or token in UNICODE_EMOJI
                or token in UNICODE_EMOJI_ALIAS
            ),
            "num_unique_words": len(set(token.text for token in doc)),
            "num_adjectives": 0,
            "num_nouns": 0,
            "num_pronouns": 0,
            "num_adverbs": 0,
            "num_conjunctions": 0,
            "num_numerals": 0,
            "num_particles": 0,
            "num_proper_nouns": 0,
            "num_verbs": 0,
            "num_contractions": 0,
            "num_punctuation_mks": 0
        }

        for token in doc:
            if token.text in CONTRACTIONS:
                features["num_contractions"] += 1

            if token.pos_ in POS_MAP:
                column_key = POS_MAP[token.pos_]
                features[column_key] += 1

        clean_tweet = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+://\S+)", " ", doc.text).split())
        features["sentiment"] = parse_sentiment(clean_tweet)

        all_features.append(features)

    return all_features


def parse_sentiment(tweet):
    """
    Utility function to classify sentiment of passed tweet
    using textblob's sentiment method
    """

    # Create TextBlob object of tweet text
    parsed = TextBlob(tweet)
    # set sentiment
    if parsed.sentiment.polarity > 0:
        return 1
    elif parsed.sentiment.polarity == 0:
        return 0
    else:
        return -1


split_by_lang = [{"lang": lang, "df": tweets_df[tweets_df["language"] == lang]} for lang in SPACY_LANGS]
for item in split_by_lang:
    nlp = spacy.load(item["lang"])
    emoji = Emoji(nlp, merge_spans=False)
    nlp.add_pipe(emoji, first=True)

    tweet_ids = item["df"].index.tolist()
    texts = item["df"]["combined_text"].tolist()
    if len(texts):
        spacy_features = extract_linguistic_features(texts, tweet_ids, nlp)
        temp_df = pd.DataFrame.from_records(spacy_features)
        temp_df.set_index("id", inplace=True)

        item["df"] = item["df"].merge(temp_df, how="left", on="id")

# %% [markdown]
# After all linguistic features have been extracted, we combine the various language-specific dataframes back into
# one, store the column names for use later, and begin scaling. We've collected a wide range of numeric data, and have categorical data in the form of the Textblob sentiment scores, and all need to be scaled. To do this efficiently, we set up a nested series of Scikit-Learn Pipelines, contained inside a ColumnTransformer, which we then use to scale all our data at once. Our numeric data is scaled using Scikit-Learn's RobustScaler, which helps avoid distortion due to outliers. The
# categorical sentiment data is transformed using Scikit-Learn's OneHotEncoder.
#
# After scaling, we split the data into training and testing sets, using Scikit-Learn's train_test_split utility
# function.

# %%
X = pd.concat([lang_item["df"] for lang_item in split_by_lang], sort=False)
X.head()
# Out:
#                                                         combined_text  \
# id
# 930110298798854144  RT @MAStrackZi: Hörtipp: Im Interview mit dem ...
# 835552767070568448  RT @B24pt: Aubameyang bisa e Dortmund vence em...
# 645269320952483840  RT @mitakalidas: WUCKFEST ❤️🏈 #L4Z #WRTC http:...
# 735684028171354114                Kira and her allergies 😒 Legacy 👶🏾💗
# 652689058326417408  RT @LHSAAScoreboard: BARBE 33 LAFAYETTE 30 FIN...
#
#                    language  num_mentions  num_hashtags gender  num_words  \
# id
# 930110298798854144       de             2             2      M       54.0
# 835552767070568448       de             1             0      M       20.0
# 645269320952483840       de             1             2      M       12.0
# 735684028171354114       de             0             0      F        9.0
# 652689058326417408       de             1             1      M       34.0
#
#                     tweet_length  num_exclamation_pts  num_question_mks  \
# id
# 930110298798854144         297.0                  0.0               0.0
# 835552767070568448         103.0                  0.0               0.0
# 645269320952483840          64.0                  0.0               0.0
# 735684028171354114          35.0                  0.0               0.0
# 652689058326417408         205.0                  0.0               0.0
#
#                     num_periods  ...  num_pronouns  num_adverbs  \
# id                               ...
# 930110298798854144          7.0  ...           0.0          0.0
# 835552767070568448          2.0  ...           0.0          0.0
# 645269320952483840          1.0  ...           0.0          0.0
# 735684028171354114          0.0  ...           0.0          0.0
# 652689058326417408          3.0  ...           0.0          0.0
#
#                     num_conjunctions  num_numerals  num_particles  \
# id
# 930110298798854144               0.0           0.0            0.0
# 835552767070568448               0.0           0.0            0.0
# 645269320952483840               0.0           0.0            0.0
# 735684028171354114               0.0           0.0            0.0
# 652689058326417408               0.0           0.0            0.0
#
#                     num_proper_nouns  num_verbs  num_contractions  \
# id
# 930110298798854144               0.0        0.0               0.0
# 835552767070568448               0.0        0.0               0.0
# 645269320952483840               0.0        0.0               0.0
# 735684028171354114               0.0        0.0               0.0
# 652689058326417408               0.0        0.0               0.0
#
#                     num_punctuation_mks  sentiment
# id
# 930110298798854144                  0.0        1.0
# 835552767070568448                  0.0        0.0
# 645269320952483840                  0.0        0.0
# 735684028171354114                  0.0        0.0
# 652689058326417408                  0.0       -1.0
#
# [5 rows x 26 columns]

# %%
y = np.array(X["gender"].map({"M": 0, "F": 1}))

X.drop(columns=["gender", "language", "combined_text"], inplace=True)
column_labels = pd.get_dummies(X, columns=["sentiment"]).columns.tolist()

# Scale numeric features
numeric_features = ["num_mentions", "num_hashtags", "num_nouns", "num_pronouns", "num_adjectives", "num_particles",
                    "num_words", "tweet_length", "num_exclamation_pts", "num_question_mks", "num_periods", "num_verbs",
                    "num_hyphens", "num_capitals", "num_emoticons", "num_unique_words", "num_conjunctions",
                    "num_numerals", "num_contractions", "num_adverbs", "num_proper_nouns", "num_punctuation_mks"]
numeric_transformer = Pipeline(steps=[
    ("robust", RobustScaler())
])

categorical_features = ["sentiment"]
categorical_transformer = Pipeline(steps=[
    ("onehot", OneHotEncoder(categories="auto"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)
X = preprocessor.fit_transform(X)

# Split into train and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=20000, random_state=42)

# %% [markdown]
# Now that we've collected and scaled all our data, we can start using it to train and test models. We'll be using
# the Light Gradient Boosting Machine (LightGBM) family of algorithms developed by Microsoft, which delivers the full
# predictive power of Gradient Boosting Classification while offering a considerable speed advantage over the
# counterparts available from libraries like Scikit-Learn.
#
# I've chosen to use Gradient Boosting with cross-validation as my model for this task because of its iterative and
# self-correcting internal logic. On its own, gradient boosting classification uses multiple (often dozens)
# rounds of internal decision trees, each working in sequence to make predictions and learn from the trees that came
# before. By the time the algorithm has reached the end of the sequence of trees defined by the user, the chain of
# estimators has experimented with the weighting of the features available and arrived at its best guess at how those
# features are related to the target variable and a model for predicting it.
#
# With the addition of k-fold cross-validation, the final model derived from training is made even stronger. In each
# round of CV, the model has access to k - 1 parts of the data, with the final part being held out as that round's
# "test" set. In this fashion, we can arrive at the best-performing model possible.
#
# In the below cell, we define two helper functions that we will use to perform cross-validation with LightGBM. We will also be
# using early stopping in all boosting processes. Although each round of cross-validation will have up to 1000 boosting
# estimators available, if the model goes through 50 estimators without improvement, it will end iteration and move on
# to the next round of CV.
#
# To measure model improvement, we will be using the ROC-AUC scoring metric. This measure provides a good indicator of
# how the model is doing against each set of validation data. It takes into account both the true positive and false
# positive rate to create a composite score that measures how well the model is doing at distinguishing between positive
# negative predictions of a Twitter user's gender.

# %%
def eval_lgb_results(hyperparams, iteration):
    """
    Scoring helper for grid and random search. Returns CV score from the given
    hyperparameters
    """

    # Find optimal n_estimators using early stopping
    if "n_estimators" in hyperparams.keys():
        del hyperparams["n_estimators"]

    # Perform n_folds CV
    cv_res = lgb.cv(
        params=hyperparams,
        train_set=train_set,
        num_boost_round=1000,
        nfold=5,
        early_stopping_rounds=50,
        metrics=["auc", "accuracy"],
        seed=42
    )

    # Return CV results
    score = cv_res["auc-mean"][-1]
    estimators = len(cv_res["auc-mean"])
    hyperparams["n_estimators"] = estimators

    return [score, hyperparams, iteration]


def light_random_search(param_grid, max_evals=5):
    # Dataframe to store results
    results = pd.DataFrame(columns=["score", "params", "iteration"], index=list(range(max_evals)))

    # Select max_eval combinations of params to check
    for i in range(max_evals):
        iter_params = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
        results.loc[i, :] = eval_lgb_results(iter_params, i)

    # Sort by best score
    results.sort_values("score", ascending=False, inplace=True)
    results.reset_index(inplace=True)
    return results

# %% [markdown]
# To take full advantage of LightGBM's capabilities, we convert our training data into a LightGBM Dataset object. We
# then begin training a Gradient Boosting model on our data. The performance and behavior of Gradient
# Boosting models depends greatly on the value of certain model parameters, also known as hyperparameters. We could
# pick these values at random and hope for the best, but that would be an uncertain and unreliable process. Instead,
# we'll first define a range for many of those parameters, and then use a fifteen-fold Randomized Search to zero in on a
# strong set of candidates. Each iteration of the search will select a random from our defined ranges for each param,
# and then conduct k-fold cross-validation, keeping track of each iteration's score using the ROC-AUC metric.
#
# The randomized search should take ~12 minutes to complete.

# %%
train_set = lgb.Dataset(data=X_train, label=y_train)

param_grid = {
    'boosting_type': ['gbdt'],
    'num_leaves': list(range(20, 150)),
    'learning_rate': list(np.logspace(np.log10(0.005), np.log10(0.5), base=10, num=1000)),
    'subsample_for_bin': list(range(20000, 300000, 20000)),
    'min_child_samples': list(range(20, 500, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.6, 1, 10)),
    'subsample': list(np.linspace(0.5, 1, 100)),
    'is_unbalance': [False],
    "first_metric_only": [True]
}

random_results = light_random_search(param_grid, max_evals=15)
print('The best validation score was {:.5f}'.format(random_results.loc[0, 'score']))
print('\nThe best hyperparameters were:')

pprint(random_results.loc[0, 'params'])
# Out:
# The best validation score was 0.87497
#
# The best hyperparameters were:
# {'boosting_type': 'gbdt',
#  'colsample_bytree': 0.7333333333333333,
#  'first_metric_only': True,
#  'is_unbalance': False,
#  'learning_rate': 0.11921952350468601,
#  'min_child_samples': 250,
#  'n_estimators': 852,
#  'num_leaves': 96,
#  'reg_alpha': 0.4693877551020408,
#  'reg_lambda': 0.22448979591836732,
#  'subsample': 0.5707070707070707,
#  'subsample_for_bin': 100000}

# %% [markdown]
# After our fifteen iterations of Random Search, we train a new model with the best set of parameters identified, and test
# it against the data we held out earlier, which the model has not seen. We'll also take a look at some visualizations to get a better sense of what's happening here, specifically:
#
# - Which features are contributing most to the decisions the model is making
# - A Confusion Matrix breaking down the precision, recall, and f1 score of the model

# %%
# Get the best params from the random search
rsearch_params = random_results.loc[0, "params"]

# Create, train, and test model with the derived params
model = lgb.LGBMClassifier(**rsearch_params, random_state=42)
model.fit(X_train, y_train)

preds = model.predict(X_test)
roc_auc = roc_auc_score(y_test, preds)
pr_score = average_precision_score(y_test, preds)

print("The best model from random search scores {:.5f} ROC-AUC on the test set and has an average precision of {:.5f}"
      .format(roc_auc, pr_score))
# Out:
# The best model from random search scores 0.79585 ROC-AUC on the test set and has an average precision of 0.73577

# %%
# Plot feature importances
importances = model.feature_importances_
tuples = sorted(zip(column_labels, importances), key=lambda x: x[1])

# Strip out features with zero importance
tuples = [x for x in tuples if x[1] > 0]
feature_names, values = zip(*tuples)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax1.set_title("Random Search Feature Importances")
ax1.barh(np.arange(len(values)), values, align="center")
ax1.set_yticks(np.arange(len(values)))
ax1.set_yticklabels(feature_names)
ax1.set_xlim(0, max(values) * 1.1)
ax1.set_ylim(-1, len(values))
ax1.set_xlabel("Feature Importance")
ax1.set_ylabel("Features")

# Plot Confusion Matrix
cm = confusion_matrix(y_test, preds)
labels = ['Male', 'Female']
sns.heatmap(cm, xticklabels=labels, yticklabels=labels, annot=True, fmt='d', cmap="Blues", vmin=0.2)
ax2.set_title("Confusion Matrix")
ax2.set_ylabel("Ground Truth")
ax2.set_xlabel("Predictions")

plt.tight_layout()
plt.show()

# %% [markdown]
# From the above visualizations, we can see that the use of punctuation played a very strong role in the model's decisions - the top three features in terms of importance are punctation-related!
#
# Digging a little deeper, we can leverage the SHaply Additive exPlanations (SHAP) library to get a sense of how the various features we've collected push the model to make a prediction of a user's gender. This library calculates Shaply values for all the features we've used, which captures the average marginal contribution of each feature to the model's predictions. To cut down on processing times, we'll just examine the predictions that the model was most confident of, i.e. above 98% confidence.

# %%
high_probability_preds - X_test[preds >= 0.98]

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    explainer = shap.TreeExplainer(model)
    expected_value = explainer.expected_value
    shap_values = explainer.shap_values(T)[1]

# %% [markdown]
# Let's take a broader look at the impact of all the features in one. We can visualize this using a SHAP summary plot:

# %%
shap.summary_plot(shap_values, features, feature_names=column_labels, class_names=["Male", "Female"])

# %% [markdown]
# In the above, we can see that several features, shown here at the bottom of the plot, had virtually no impact on the classification, and can likely be safely discarded in futrue iterations. Towards the top, we can get a sense for how a higher value for a given feature affected the model's choice.
#
# For example, let's look at the top line. The blue dots indicate a low value for the chosen feature, in this case num_adverbs. We can see there is a concentrated blob of blue on the left-hand side, indicating that the model believes lower numbers of adverbs is indicative of a male author (male was coded to 0 in our target data). Conversely, we can see that all the samples with higher numbers of adverbs are on the right-hand side, indicating a prediction of female. Interestingly, although the effect on the model's prediction is relatively weaker, we can see clear high/low divides on either side of the line for several other features, including positive sentiment, tweet length, and number of unique words used.
#
# Next, let's use our focus on the samples the model is most confident about and plot a SHAP decision plot, showing our model's typical prediction paths, to see what the model's various predictions have in common and what stands out.

# %%
shap.decision_plot(expected_value, shap_values, T, feature_order="hclust", link="logit", feature_names=column_labels)

# %% [markdown]
# To wrap up, as we can see in the readout of our predictions above, our model got a score of just under 0.80 ROC-AUC on the test set, while scoring over 0.80 in cross-validation. Not bad! In a perfect world with a much more powerful computer available, we could do a lot better by feeding the results of our random search into an exhaustive grid search. While I will not implement this here due to the computation and time cost, we can sketch out how it would work.
#
# Starting from the best hyperparameter values derived from random search, we would define new, focused ranges around
# each one, and feed that grid of params into an exhaustive search. In the cell below we define a helper method that
# would conduct the search for us.

# %%
def light_grid_search(param_grid):
    results = pd.DataFrame(columns=["score", "params", "iteration"])

    # Get every possible combination of params from the grid
    keys, grid_vals = zip(*param_grid.items())

    # Iterate over every possible combination of hyperparameters
    for i, v in enumerate(product(*grid_vals)):
        iter_params = dict(zip(keys, v))
        results.loc[i, :] = eval_lgb_results(iter_params, i)

    # Sort by best score
    results.sort_values("score", ascending=False, inplace=True)
    results.reset_index(inplace=True)
    return results

# %% [markdown]
# To ensure the results of the grid search would be directly comparable to their randomized counterparts, we'd use the
# same process of k-fold cross-validation. After the search finishes running, we'd follow the same steps we did above -
# taking the best hyperparameters, using them to train a model on our data, and then seeing how the model did against
# our held-out test set.
